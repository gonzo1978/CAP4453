# %% [markdown]
# <a href="https://colab.research.google.com/github/gonzo1978/CAP4453/blob/main/HW0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Go to https://colab.research.google.com/ create a new notebook. Create a google account in case you do not have one.
# 2. Add a text section and write your name
# 3. Share the notebook with me (gonzalo.vacacastano@ucf.edu) and grader (yousafadeel1993@gmail.com). Click share in top right. Make sure that the link is shared as restricted.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. get the link, copy it and paste it as your submission in webcourses
#
# ![image.png](data:image/png;base64,...)
